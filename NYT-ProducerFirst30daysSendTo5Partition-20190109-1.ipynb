# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Jan  6 11:38:51 2019

@author: RB
"""
from kafka import KafkaProducer
from datetime import datetime
import pandas as pd
import csv
import math

print('\nStartTime is:',datetime.now().strftime("%c"))
fileLocation = r'C:\Everything\01SRH-BDBA Acads\Blk2-DataEngr\NYTaxi\testingData\yellow_tripdata_2018-06-full.csv'
topicName = 'TestNYTJune30days'
producer = KafkaProducer(bootstrap_servers='localhost:9092')
maxRows2Read = 10000000                            # Specify the maximum number of rows to read from the csv
rowsReadcount = 0
countSent2Producer = 0
boundMatchRowsCount = 0
boundNotMatchRowsCount = 0
boundLowerPUDatetime = '2018-06-01 00:00:00'   # the pickup datetime from csv to be greater or equal to this
boundUpperPUDatetime = '2018-07-01 00:00:00'   # the pickup datetime from csv to be lower than this

with open(fileLocation, "r") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",")
    for row in csv_reader:
        rowsReadcount = rowsReadcount + 1
        if rowsReadcount % 100000 == 0:    
            print(f'Processing csv row number {rowsReadcount} at ', datetime.now().strftime("%c"))
        if rowsReadcount == (maxRows2Read + 1):
            print('Reached rows to read limit set by user')
#            print('Reached limit for first 24 hours and exiting last entry should have PickUp time of 01-06-2018  23:43:00')
            break
        try:
            row_tpep_pickup_datetime = row[1]
        except:
            print(f'Skipped row as Error during PU date assignment for row={rowsReadcount}')
            continue
#        print(f'row_tpep_pickup_datetime={row_tpep_pickup_datetime}')
        if (row_tpep_pickup_datetime < boundUpperPUDatetime and row_tpep_pickup_datetime >= boundLowerPUDatetime):
            joinedRow = ','.join(row)
            producer.send(topicName, joinedRow.encode('utf-8'))
            countSent2Producer = countSent2Producer + 1
            if countSent2Producer % 500000 == 0:
                print(f'Sent {rowsReadcount} row as the {countSent2Producer} th message to Kafka')
        elif not (row[0] == 'VendorID'):
#            print(f'Row {rowsReadcount} not sent to producer, row PUDatetime={row_tpep_pickup_datetime} and outside bounds')
            boundNotMatchRowsCount = boundNotMatchRowsCount + 1
# =============================================================================
#         if rowsReadcount % 50000 == 0:
#             print(f'Row={rowsReadcount}, Contents are:::\n{joinedRow}' )
#             print(f'Processed the {rowsReadcount} th row of csv and sent to Kafka' )
# =============================================================================

print("\n\nProcessed %d rows from csv\nSent %d messages to Kafka\nNOT SENT %d rows as OB" %(rowsReadcount-1, countSent2Producer, boundNotMatchRowsCount))
print('\nEndTime is:',datetime.now().strftime("%c"))
# Out:
# StartTime is: Wed Jan  9 23:08:02 2019
# Skipped row as Error during PU date assignment for row=2
# Processing csv row number 100000 at  Wed Jan  9 23:08:25 2019
# Processing csv row number 200000 at  Wed Jan  9 23:08:40 2019
# Processing csv row number 300000 at  Wed Jan  9 23:09:01 2019
# Processing csv row number 400000 at  Wed Jan  9 23:09:32 2019
# Processing csv row number 500000 at  Wed Jan  9 23:10:34 2019
# Sent 500276 row as the 500000 th message to Kafka
# Processing csv row number 600000 at  Wed Jan  9 23:11:41 2019
# Processing csv row number 700000 at  Wed Jan  9 23:12:45 2019
# Processing csv row number 800000 at  Wed Jan  9 23:13:48 2019
# Processing csv row number 900000 at  Wed Jan  9 23:14:51 2019
# Processing csv row number 1000000 at  Wed Jan  9 23:15:59 2019
# Sent 1000277 row as the 1000000 th message to Kafka
# Processing csv row number 1100000 at  Wed Jan  9 23:17:07 2019
# Processing csv row number 1200000 at  Wed Jan  9 23:18:14 2019
# Processing csv row number 1300000 at  Wed Jan  9 23:19:22 2019
# Processing csv row number 1400000 at  Wed Jan  9 23:20:24 2019
# Processing csv row number 1500000 at  Wed Jan  9 23:21:29 2019
# Sent 1500277 row as the 1500000 th message to Kafka
# Processing csv row number 1600000 at  Wed Jan  9 23:22:34 2019
# Processing csv row number 1700000 at  Wed Jan  9 23:23:20 2019
# Processing csv row number 1800000 at  Wed Jan  9 23:24:03 2019
# Processing csv row number 1900000 at  Wed Jan  9 23:25:01 2019
# Processing csv row number 2000000 at  Wed Jan  9 23:26:04 2019
# Sent 2000278 row as the 2000000 th message to Kafka
# Processing csv row number 2100000 at  Wed Jan  9 23:27:00 2019
# Processing csv row number 2200000 at  Wed Jan  9 23:27:58 2019
# Processing csv row number 2300000 at  Wed Jan  9 23:28:58 2019
# Processing csv row number 2400000 at  Wed Jan  9 23:29:52 2019
# Processing csv row number 2500000 at  Wed Jan  9 23:30:43 2019
# Sent 2500286 row as the 2500000 th message to Kafka
# Processing csv row number 2600000 at  Wed Jan  9 23:31:30 2019
# Processing csv row number 2700000 at  Wed Jan  9 23:32:17 2019
# Processing csv row number 2800000 at  Wed Jan  9 23:33:02 2019
# Processing csv row number 2900000 at  Wed Jan  9 23:33:47 2019
# Processing csv row number 3000000 at  Wed Jan  9 23:34:41 2019
# Sent 3000327 row as the 3000000 th message to Kafka
# Processing csv row number 3100000 at  Wed Jan  9 23:35:33 2019
# Processing csv row number 3200000 at  Wed Jan  9 23:36:06 2019
# Processing csv row number 3300000 at  Wed Jan  9 23:37:17 2019
# Processing csv row number 3400000 at  Wed Jan  9 23:38:16 2019
# Processing csv row number 3500000 at  Wed Jan  9 23:39:07 2019
# Sent 3500329 row as the 3500000 th message to Kafka
# Processing csv row number 3600000 at  Wed Jan  9 23:40:03 2019
# Processing csv row number 3700000 at  Wed Jan  9 23:40:55 2019
# Processing csv row number 3800000 at  Wed Jan  9 23:41:44 2019
# Processing csv row number 3900000 at  Wed Jan  9 23:42:31 2019
# Processing csv row number 4000000 at  Wed Jan  9 23:43:19 2019
# Sent 4000379 row as the 4000000 th message to Kafka
# Processing csv row number 4100000 at  Wed Jan  9 23:44:11 2019
# Processing csv row number 4200000 at  Wed Jan  9 23:45:14 2019
# Processing csv row number 4300000 at  Wed Jan  9 23:46:01 2019
# Processing csv row number 4400000 at  Wed Jan  9 23:46:47 2019
# Processing csv row number 4500000 at  Wed Jan  9 23:47:35 2019
# Sent 4500396 row as the 4500000 th message to Kafka
# Processing csv row number 4600000 at  Wed Jan  9 23:48:28 2019
# Processing csv row number 4700000 at  Wed Jan  9 23:49:24 2019
# Processing csv row number 4800000 at  Wed Jan  9 23:50:27 2019
# Processing csv row number 4900000 at  Wed Jan  9 23:51:17 2019
# Processing csv row number 5000000 at  Wed Jan  9 23:52:07 2019
# Sent 5000410 row as the 5000000 th message to Kafka
# Processing csv row number 5100000 at  Wed Jan  9 23:53:06 2019
# Processing csv row number 5200000 at  Wed Jan  9 23:54:04 2019
# Processing csv row number 5300000 at  Wed Jan  9 23:55:07 2019
# Processing csv row number 5400000 at  Wed Jan  9 23:56:13 2019
# Processing csv row number 5500000 at  Wed Jan  9 23:56:56 2019
# Sent 5500413 row as the 5500000 th message to Kafka
# Processing csv row number 5600000 at  Wed Jan  9 23:57:45 2019
# Processing csv row number 5700000 at  Wed Jan  9 23:58:34 2019
# Processing csv row number 5800000 at  Wed Jan  9 23:59:38 2019
# Processing csv row number 5900000 at  Thu Jan 10 00:00:34 2019
# Processing csv row number 6000000 at  Thu Jan 10 00:01:12 2019
# Sent 6000415 row as the 6000000 th message to Kafka
# Processing csv row number 6100000 at  Thu Jan 10 00:02:00 2019
# Processing csv row number 6200000 at  Thu Jan 10 00:02:48 2019
# Processing csv row number 6300000 at  Thu Jan 10 00:03:46 2019
# Processing csv row number 6400000 at  Thu Jan 10 00:04:45 2019
# Processing csv row number 6500000 at  Thu Jan 10 00:05:43 2019
# Sent 6500416 row as the 6500000 th message to Kafka
# Processing csv row number 6600000 at  Thu Jan 10 00:06:30 2019
# Processing csv row number 6700000 at  Thu Jan 10 00:07:19 2019
# Processing csv row number 6800000 at  Thu Jan 10 00:08:10 2019
# Processing csv row number 6900000 at  Thu Jan 10 00:09:08 2019
# Processing csv row number 7000000 at  Thu Jan 10 00:09:59 2019
# Sent 7000418 row as the 7000000 th message to Kafka
# Processing csv row number 7100000 at  Thu Jan 10 00:10:57 2019
# Processing csv row number 7200000 at  Thu Jan 10 00:11:55 2019
# Processing csv row number 7300000 at  Thu Jan 10 00:12:46 2019
# Processing csv row number 7400000 at  Thu Jan 10 00:13:39 2019
# Processing csv row number 7500000 at  Thu Jan 10 00:14:41 2019
# Sent 7500420 row as the 7500000 th message to Kafka
# Processing csv row number 7600000 at  Thu Jan 10 00:15:44 2019
# Processing csv row number 7700000 at  Thu Jan 10 00:16:44 2019
# Processing csv row number 7800000 at  Thu Jan 10 00:17:45 2019
# Processing csv row number 7900000 at  Thu Jan 10 00:18:37 2019
# Processing csv row number 8000000 at  Thu Jan 10 00:19:28 2019
# Sent 8000422 row as the 8000000 th message to Kafka
# Processing csv row number 8100000 at  Thu Jan 10 00:20:29 2019
# Processing csv row number 8200000 at  Thu Jan 10 00:21:37 2019
# Processing csv row number 8300000 at  Thu Jan 10 00:22:43 2019
# Processing csv row number 8400000 at  Thu Jan 10 00:23:53 2019
# Processing csv row number 8500000 at  Thu Jan 10 00:24:53 2019
# Sent 8500439 row as the 8500000 th message to Kafka
# Processing csv row number 8600000 at  Thu Jan 10 00:25:43 2019
# Processing csv row number 8700000 at  Thu Jan 10 00:26:45 2019
#
#
# Processed 8713832 rows from csv
# Sent 8713307 messages to Kafka
# NOT SENT 524 rows as OB
#
# EndTime is: Thu Jan 10 00:26:53 2019
