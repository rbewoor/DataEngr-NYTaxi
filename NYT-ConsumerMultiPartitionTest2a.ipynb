# %%
# CONSUMER 1    CONSUMER 1   Test 2 without Mongo Write
# -*- coding: utf-8 -*-
"""
Created on Sun Jan  6 11:35:20 2019

@author: RB
"""
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads
from datetime import datetime

print('\nStart time of consumer program: ', datetime.now().strftime("%c"))

countDocsWritten1 = 0
countDocsWritten2 = 0
msgsReadCount = 0
topicName = 'TestNYTFullJuneDb10'

consumer = KafkaConsumer(
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
#     auto_offset_reset='latest',   # default is latest
     enable_auto_commit=True,
     auto_commit_interval_ms=2000,
     group_id='my-group4')
#     consumer_timeout_ms=5000)   #consumer_timeout_ms (int) – number of milliseconds to block during 
                                 #    message iteration before raising StopIteration (i.e., ending the 
                                 #    iterator). Default block forever [float(‘inf’)].
consumer.subscribe(topicName)

client1 = MongoClient('localhost:27017')
client2 = MongoClient('localhost:27017')
collection1 = client1.TestNYTFullJuneDb13.TestNYTFullJuneColJun01to12
collection2 = client2.TestNYTFullJuneDb13.TestNYTFullJuneColJun13to24

boundLowerPUDatetime1 = '2018-06-01 00:00:00'   # the pickup datetime from csv to be greater or equal to this
boundUpperPUDatetime1 = '2018-06-13 00:00:00'   # the pickup datetime from csv to be lower than this
boundLowerPUDatetime2 = '2018-06-13 00:00:00'   # the pickup datetime from csv to be greater or equal to this
boundUpperPUDatetime2 = '2018-06-25 00:00:00'   # the pickup datetime from csv to be lower than this

for message in consumer:
    msgsReadCount = msgsReadCount + 1
    NYTNewRowJsonBuiltUpAsString = "{}"
    #print(f'Msg number {msgsReadCount}::::\nFull message received from Kafka::\n', message)
    msgAsString = message.value.decode("utf-8")
    if msgAsString == '':
        print('IGNORED SECOND ROW with all commans, CONTINUING to end of the for loop')
        continue
    elif msgAsString[0:8] == 'VendorID':
        print('IGNORED FIRST ROW with columns names, CONTINUING to end of the for loop')
        continue
    elif msgAsString.count(',') == 16:
        msgAsList = msgAsString.split(",")
        trip_distanceAsString = str(msgAsList[4])
        if trip_distanceAsString[0:1] == '.':        # a 0 value comes as  .00  so checking and making as 0.00
            trip_distanceAsString = '0' + trip_distanceAsString
        NYTNewRowJsonBuiltUpAsString='{' +                                      \
        '"VendorID" : ' + str(msgAsList[0]) + ', ' +                            \
        '"tpep_pickup_datetime" : ' + '"' + str(msgAsList[1]) +  '"' + ', ' +   \
        '"tpep_dropoff_datetime" : ' + '"' + str(msgAsList[2]) +  '"' + ', ' +  \
        '"passenger_count" : ' + str(msgAsList[3]) + ', ' +                     \
        '"trip_distance" : ' + trip_distanceAsString + ', ' +                   \
        '"RatecodeID" : ' + str(msgAsList[5]) + ', ' +                          \
        '"store_and_fwd_flag" : ' + '"' + str(msgAsList[6]) + '"' + ', ' +      \
        '"PULocationID" : ' + str(msgAsList[7]) + ', ' +                        \
        '"DOLocationID" : ' + str(msgAsList[8]) + ', ' +                        \
        '"payment_type" : ' + str(msgAsList[9]) + ', ' +                        \
        '"fare_amount" : ' + str(msgAsList[10]) + ', ' +                        \
        '"extra" : ' + str(msgAsList[11]) + ', ' +                              \
        '"mta_tax" : ' + str(msgAsList[12]) + ', ' +                            \
        '"tip_amount" : ' + str(msgAsList[13]) + ', ' +                         \
        '"tolls_amount" : ' + str(msgAsList[14]) + ', ' +                       \
        '"improvement_surcharge" : ' + str(msgAsList[15]) + ', ' +              \
        '"total_amount" : ' + str(msgAsList[16]) + '}'
        #print(f'Msg {msgsReadCount} - JSON built as=\n{NYTNewRowJsonBuiltUpAsString}')
        if ( str(msgAsList[1]) < boundUpperPUDatetime1 and str(msgAsList[1]) >= boundLowerPUDatetime1 ):
            try:
                collection1.insert_one(loads(NYTNewRowJsonBuiltUpAsString))
                #print(f"Collection 1 -- NO ERROR for {msgsReadCount} th message insert")
                countDocsWritten1 = countDocsWritten1 + 1
                if countDocsWritten1 % 50000 == 0:
                    print(f"Collection 1 - write SUCCESS - {msgsReadCount} th message as {countDocsWritten1} th insert")
                if countDocsWritten1 % 250000 == 0:
                    print(f'Msg {msgsReadCount} - JSON built as=\n{NYTNewRowJsonBuiltUpAsString}')
            except Exception as e:
                print(f'Collection 1 ERROR Insert :: {msgsReadCount} th message\nError:: ', type(e), e)
        elif ( str(msgAsList[1]) < boundUpperPUDatetime2 and str(msgAsList[1]) >= boundLowerPUDatetime2 ):
            try:
                collection2.insert_one(loads(NYTNewRowJsonBuiltUpAsString))
                #print(f"Collection 2 -- NO ERROR for {msgsReadCount} th message insert")
                countDocsWritten2 = countDocsWritten2 + 1
                if countDocsWritten2 % 50000 == 0:
                    print(f"Collection 2 - write SUCCESS - {msgsReadCount} th message as {countDocsWritten2} th insert")
                if countDocsWritten2 % 500000 == 0:
                    print(f'Msg {msgsReadCount} - JSON built as=\n{NYTNewRowJsonBuiltUpAsString}')
            except Exception as e:
                print(f'Collection 2 ERROR Insert :: {msgsReadCount} th message\nError:: ', type(e), e)
    else:
        print(f"{msgsReadCount} th message NOT having 16 commas so IGNORED MESSAGE")


print('\nExited FOR LOOP\nRead total %d messages from Kafka' %(msgsReadCount))
print('\nWritten %d documents to Mongo Collection1' %(countDocsWritten1))
print('\nWritten %d documents to Mongo Collection2' %(countDocsWritten2))
print('\nDone processing. Normal exit from program at: ', datetime.now().strftime("%c"))
#
# ways to copy a dictionary value      dict2 = dict(dict1)   OR   dict2 = dict1.copy()
#
# Out:
# Start time of consumer program:  Sun Jan  6 16:45:21 2019
# Collection 1 - write SUCCESS - 50000 th message as 50000 th insert
# Collection 1 - write SUCCESS - 100000 th message as 100000 th insert
# Collection 1 - write SUCCESS - 150000 th message as 150000 th insert
# Collection 1 - write SUCCESS - 200000 th message as 200000 th insert
# Collection 1 - write SUCCESS - 250000 th message as 250000 th insert
# Msg 250000 - JSON built as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-03 11:26:48", "tpep_dropoff_datetime" : "2018-06-03 11:29:29", "passenger_count" : 3, "trip_distance" : 0.41, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 264, "DOLocationID" : 264, "payment_type" : 2, "fare_amount" : 4, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 4.8}
# Collection 1 - write SUCCESS - 300000 th message as 300000 th insert
# Collection 1 - write SUCCESS - 350000 th message as 350000 th insert
# Collection 1 - write SUCCESS - 400000 th message as 400000 th insert
# Collection 1 - write SUCCESS - 450000 th message as 450000 th insert
# Collection 1 - write SUCCESS - 500000 th message as 500000 th insert
# Msg 500000 - JSON built as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-06 01:09:51", "tpep_dropoff_datetime" : "2018-06-06 01:29:21", "passenger_count" : 1, "trip_distance" : 10.85, "RatecodeID" : 5, "store_and_fwd_flag" : "N", "PULocationID" : 48, "DOLocationID" : 265, "payment_type" : 1, "fare_amount" : 70, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 16.26, "tolls_amount" : 10.5, "improvement_surcharge" : 0.3, "total_amount" : 97.56}
# Collection 1 - write SUCCESS - 550000 th message as 550000 th insert
# Collection 1 - write SUCCESS - 600000 th message as 600000 th insert
# Collection 1 - write SUCCESS - 650000 th message as 650000 th insert
# Collection 1 - write SUCCESS - 700000 th message as 700000 th insert
# Collection 1 - write SUCCESS - 750000 th message as 750000 th insert
# Msg 750000 - JSON built as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-08 12:14:27", "tpep_dropoff_datetime" : "2018-06-08 12:19:37", "passenger_count" : 1, "trip_distance" : 0.50, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 90, "DOLocationID" : 186, "payment_type" : 1, "fare_amount" : 5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 1, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 6.8}
# Collection 1 - write SUCCESS - 800000 th message as 800000 th insert
# Collection 1 - write SUCCESS - 850000 th message as 850000 th insert
# Collection 1 - write SUCCESS - 900000 th message as 900000 th insert
# Collection 1 - write SUCCESS - 950000 th message as 950000 th insert
# Collection 1 - write SUCCESS - 1000000 th message as 1000000 th insert
# Msg 1000000 - JSON built as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-11 05:17:50", "tpep_dropoff_datetime" : "2018-06-11 05:27:17", "passenger_count" : 1, "trip_distance" : 3.43, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 100, "DOLocationID" : 87, "payment_type" : 1, "fare_amount" : 11.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 5, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 17.8}
# Collection 1 - write SUCCESS - 1050001 th message as 1050000 th insert
# Collection 1 - write SUCCESS - 1100002 th message as 1100000 th insert
# Collection 1 - write SUCCESS - 1150008 th message as 1150000 th insert
# Collection 2 - write SUCCESS - 1236024 th message as 50000 th insert
# Collection 2 - write SUCCESS - 1286026 th message as 100000 th insert
# Collection 2 - write SUCCESS - 1336026 th message as 150000 th insert
# Collection 2 - write SUCCESS - 1386026 th message as 200000 th insert
# Collection 2 - write SUCCESS - 1436026 th message as 250000 th insert
# Collection 2 - write SUCCESS - 1486026 th message as 300000 th insert
# Collection 2 - write SUCCESS - 1536026 th message as 350000 th insert
# Collection 2 - write SUCCESS - 1586026 th message as 400000 th insert
# Collection 2 - write SUCCESS - 1636026 th message as 450000 th insert
# Collection 2 - write SUCCESS - 1686026 th message as 500000 th insert
# Msg 1686026 - JSON built as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-18 09:47:40", "tpep_dropoff_datetime" : "2018-06-18 09:57:40", "passenger_count" : 1, "trip_distance" : 0.76, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 79, "DOLocationID" : 90, "payment_type" : 2, "fare_amount" : 7.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 8.3}
# Collection 2 - write SUCCESS - 1736026 th message as 550000 th insert
# Collection 2 - write SUCCESS - 1786026 th message as 600000 th insert
# Collection 2 - write SUCCESS - 1836026 th message as 650000 th insert
# Collection 2 - write SUCCESS - 1886026 th message as 700000 th insert
# Collection 2 - write SUCCESS - 1936026 th message as 750000 th insert
# Collection 2 - write SUCCESS - 1986026 th message as 800000 th insert
# Collection 2 - write SUCCESS - 2036026 th message as 850000 th insert
# Collection 2 - write SUCCESS - 2086026 th message as 900000 th insert
# Collection 2 - write SUCCESS - 2136026 th message as 950000 th insert
# Collection 2 - write SUCCESS - 2186026 th message as 1000000 th insert
# Msg 2186026 - JSON built as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-23 05:26:07", "tpep_dropoff_datetime" : "2018-06-23 05:34:45", "passenger_count" : 1, "trip_distance" : 2.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 179, "DOLocationID" : 260, "payment_type" : 1, "fare_amount" : 11, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 2, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 14.3}
# Collection 2 - write SUCCESS - 2236026 th message as 1050000 th insert
# Collection 2 - write SUCCESS - 2286026 th message as 1100000 th insert
# Collection 2 - write SUCCESS - 2336026 th message as 1150000 th insert
