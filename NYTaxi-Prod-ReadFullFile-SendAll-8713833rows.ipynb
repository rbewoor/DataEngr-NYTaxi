# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Jan  1 02:26:44 2019

@author: RB
"""
from kafka import KafkaProducer
from datetime import datetime
import pandas as pd
import csv

print('\nStartTime is:',datetime.now().strftime("%c"))
fileLocation = r'C:\Everything\01SRH-BDBA Acads\Blk2-DataEngr\NYTaxi\testingData\yellow_tripdata_2018-06-full.csv'
topicName = 'TestNYTFullJune'
producer = KafkaProducer(bootstrap_servers='localhost:9092')
rowsRead = 0
with open(fileLocation, "r") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",")
    for row in csv_reader:
        rowsRead = rowsRead + 1
        joinedRow = ','.join(row)
        producer.send(topicName, joinedRow.encode('utf-8'))
        if rowsRead % 100000 == 0:
#            print(f'Row={rowsRead}, Contents are:::\n{joinedRow}' )
            print(f'Processed the {rowsRead} th row of csv and sent to Kafka' )
# =============================================================================
#         if rowsRead == 316569:
#             print('Reached limit for first 24 hours and exiting last entry should have PickUp time of 01-06-2018  23:43:00')
#             break
# =============================================================================

print(f"\n\nProcessed {rowsRead} rows and sent")
print('\nEndTime is:',datetime.now().strftime("%c"))
# Out:
# StartTime is: Tue Jan  1 12:31:06 2019
# Processed the 100000 th row of csv and sent to Kafka
# Processed the 200000 th row of csv and sent to Kafka
# Processed the 300000 th row of csv and sent to Kafka
# Processed the 400000 th row of csv and sent to Kafka
# Processed the 500000 th row of csv and sent to Kafka
# Processed the 600000 th row of csv and sent to Kafka
# Processed the 700000 th row of csv and sent to Kafka
# Processed the 800000 th row of csv and sent to Kafka
# Processed the 900000 th row of csv and sent to Kafka
# Processed the 1000000 th row of csv and sent to Kafka
# Processed the 1100000 th row of csv and sent to Kafka
# Processed the 1200000 th row of csv and sent to Kafka
# Processed the 1300000 th row of csv and sent to Kafka
# Processed the 1400000 th row of csv and sent to Kafka
# Processed the 1500000 th row of csv and sent to Kafka
# Processed the 1600000 th row of csv and sent to Kafka
# Processed the 1700000 th row of csv and sent to Kafka
# Processed the 1800000 th row of csv and sent to Kafka
# Processed the 1900000 th row of csv and sent to Kafka
# Processed the 2000000 th row of csv and sent to Kafka
# Processed the 2100000 th row of csv and sent to Kafka
# Processed the 2200000 th row of csv and sent to Kafka
# Processed the 2300000 th row of csv and sent to Kafka
# Processed the 2400000 th row of csv and sent to Kafka
# Processed the 2500000 th row of csv and sent to Kafka
# Processed the 2600000 th row of csv and sent to Kafka
# Processed the 2700000 th row of csv and sent to Kafka
# Processed the 2800000 th row of csv and sent to Kafka
# Processed the 2900000 th row of csv and sent to Kafka
# Processed the 3000000 th row of csv and sent to Kafka
# Processed the 3100000 th row of csv and sent to Kafka
# Processed the 3200000 th row of csv and sent to Kafka
# Processed the 3300000 th row of csv and sent to Kafka
# Processed the 3400000 th row of csv and sent to Kafka
# Processed the 3500000 th row of csv and sent to Kafka
# Processed the 3600000 th row of csv and sent to Kafka
# Processed the 3700000 th row of csv and sent to Kafka
# Processed the 3800000 th row of csv and sent to Kafka
# Processed the 3900000 th row of csv and sent to Kafka
# Processed the 4000000 th row of csv and sent to Kafka
# Processed the 4100000 th row of csv and sent to Kafka
# Processed the 4200000 th row of csv and sent to Kafka
# Processed the 4300000 th row of csv and sent to Kafka
# Processed the 4400000 th row of csv and sent to Kafka
# Processed the 4500000 th row of csv and sent to Kafka
# Processed the 4600000 th row of csv and sent to Kafka
# Processed the 4700000 th row of csv and sent to Kafka
# Processed the 4800000 th row of csv and sent to Kafka
# Processed the 4900000 th row of csv and sent to Kafka
# Processed the 5000000 th row of csv and sent to Kafka
# Processed the 5100000 th row of csv and sent to Kafka
# Processed the 5200000 th row of csv and sent to Kafka
# Processed the 5300000 th row of csv and sent to Kafka
# Processed the 5400000 th row of csv and sent to Kafka
# Processed the 5500000 th row of csv and sent to Kafka
# Processed the 5600000 th row of csv and sent to Kafka
# Processed the 5700000 th row of csv and sent to Kafka
# Processed the 5800000 th row of csv and sent to Kafka
# Processed the 5900000 th row of csv and sent to Kafka
# Processed the 6000000 th row of csv and sent to Kafka
# Processed the 6100000 th row of csv and sent to Kafka
# Processed the 6200000 th row of csv and sent to Kafka
# Processed the 6300000 th row of csv and sent to Kafka
# Processed the 6400000 th row of csv and sent to Kafka
# Processed the 6500000 th row of csv and sent to Kafka
# Processed the 6600000 th row of csv and sent to Kafka
# Processed the 6700000 th row of csv and sent to Kafka
# Processed the 6800000 th row of csv and sent to Kafka
# Processed the 6900000 th row of csv and sent to Kafka
# Processed the 7000000 th row of csv and sent to Kafka
# Processed the 7100000 th row of csv and sent to Kafka
# Processed the 7200000 th row of csv and sent to Kafka
# Processed the 7300000 th row of csv and sent to Kafka
# Processed the 7400000 th row of csv and sent to Kafka
# Processed the 7500000 th row of csv and sent to Kafka
# Processed the 7600000 th row of csv and sent to Kafka
# Processed the 7700000 th row of csv and sent to Kafka
# Processed the 7800000 th row of csv and sent to Kafka
# Processed the 7900000 th row of csv and sent to Kafka
# Processed the 8000000 th row of csv and sent to Kafka
# Processed the 8100000 th row of csv and sent to Kafka
# Processed the 8200000 th row of csv and sent to Kafka
# Processed the 8300000 th row of csv and sent to Kafka
# Processed the 8400000 th row of csv and sent to Kafka
# Processed the 8500000 th row of csv and sent to Kafka
# Processed the 8600000 th row of csv and sent to Kafka
# Processed the 8700000 th row of csv and sent to Kafka
#
#
# Processed 8713833 rows and sent
#
# EndTime is: Tue Jan  1 12:50:37 2019
