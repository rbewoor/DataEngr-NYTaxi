# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Dec 31 14:08:19 2018

@author: RB
"""
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads
from datetime import datetime

print('\nStart time of consumer program: ', datetime.now().strftime("%c"))

countDocsWritten = 0
msgsReadCount = 0
topicName = 'TestNYTFullJuneButOnlyFirst12'

consumer = KafkaConsumer(
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
#     auto_offset_reset='latest',   # default is latest
     enable_auto_commit=True,
     #auto_commit_interval_ms=2000,
#     group_id='my-group1',
     consumer_timeout_ms=5000)   #consumer_timeout_ms (int) – number of milliseconds to block during 
                                 #    message iteration before raising StopIteration (i.e., ending the 
                                 #    iterator). Default block forever [float(‘inf’)].
consumer.subscribe(topicName)

client = MongoClient('localhost:27017')
collection = client.TestNYTFullJuneButOnlyFirst12Db1.TestNYTFullJuneButOnlyFirst12Col1

for message in consumer:
    msgsReadCount = msgsReadCount + 1
    NYTNewRowJsonBuiltUpAsString = "{}"
    print(f'Full message received from Kafka::\n', message)
    msgAsString = message.value.decode("utf-8")
    if msgAsString == '':
        print('IGNORED SECOND ROW with all commans, SKIPPING to end of the for loop')
        continue
    elif msgAsString[0:8] == 'VendorID':
        print('IGNORED FIRST ROW with columns names, SKIPPING to end of the for loop')
        continue
    elif msgAsString.count(',') == 16:
        msgAsList = msgAsString.split(",")
        trip_distanceAsString = str(msgAsList[4])
        if trip_distanceAsString[0:1] == '.':
            trip_distanceAsString = '0' + trip_distanceAsString
        NYTNewRowJsonBuiltUpAsString='{' +                                      \
        '"VendorID" : ' + str(msgAsList[0]) + ', ' +                            \
        '"tpep_pickup_datetime" : ' + '"' + str(msgAsList[1]) +  '"' + ', ' +   \
        '"tpep_dropoff_datetime" : ' + '"' + str(msgAsList[2]) +  '"' + ', ' +  \
        '"passenger_count" : ' + str(msgAsList[3]) + ', ' +                     \
        '"trip_distance" : ' + trip_distanceAsString + ', ' +                   \
        '"RatecodeID" : ' + str(msgAsList[5]) + ', ' +                          \
        '"store_and_fwd_flag" : ' + '"' + str(msgAsList[6]) + '"' + ', ' +      \
        '"PULocationID" : ' + str(msgAsList[7]) + ', ' +                        \
        '"DOLocationID" : ' + str(msgAsList[8]) + ', ' +                        \
        '"payment_type" : ' + str(msgAsList[9]) + ', ' +                        \
        '"fare_amount" : ' + str(msgAsList[10]) + ', ' +                        \
        '"extra" : ' + str(msgAsList[11]) + ', ' +                              \
        '"mta_tax" : ' + str(msgAsList[12]) + ', ' +                            \
        '"tip_amount" : ' + str(msgAsList[13]) + ', ' +                         \
        '"tolls_amount" : ' + str(msgAsList[14]) + ', ' +                       \
        '"improvement_surcharge" : ' + str(msgAsList[15]) + ', ' +              \
        '"total_amount" : ' + str(msgAsList[16]) + '}'
        print(f'JSON created for {msgsReadCount} th message::\n{NYTNewRowJsonBuiltUpAsString}')
        try:
            collection.insert_one(loads(NYTNewRowJsonBuiltUpAsString))
            print(f"NO ERROR for {msgsReadCount} th message insert")
            countDocsWritten = countDocsWritten + 1
            if countDocsWritten: # % 50000 == 0:
                print(f"Successful write for {msgsReadCount} message number as {countDocsWritten} the insert into Mongo")
            if countDocsWritten: # % 250000 == 0:
                print(f'{countDocsWritten} th JSON builtup as=\n{NYTNewRowJsonBuiltUpAsString}')
        except Exception as e:
            print(f'Error on Insert:: {msgsReadCount} th message\nError:: ', type(e), e)
    else:
        print(f"{msgsReadCount} th message NOT having 16 commas so IGNORED MESSAGE")


print('\nExited FOR LOOP\nRead total %d messages from Kafka' %(msgsReadCount))
print('\nWritten %d documents to MongoDb' %(countDocsWritten))
print('\nDone processing. Normal exit from program at: ', datetime.now().strftime("%c"))
#
# ways to copy a dictionary value      dict2 = dict(dict1)   OR   dict2 = dict1.copy()
#
# Out:
# Start time of consumer program:  Tue Jan  1 15:33:36 2019
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=0, timestamp=1546342876794, timestamp_type=0, key=None, value=b'VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,RatecodeID,store_and_fwd_flag,PULocationID,DOLocationID,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=235, serialized_header_size=-1)
# IGNORED FIRST ROW with columns names, SKIPPING to end of the for loop
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=1, timestamp=1546342876796, timestamp_type=0, key=None, value=b'', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=0, serialized_header_size=-1)
# IGNORED SECOND ROW with all commans, SKIPPING to end of the for loop
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=2, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:15:40,2018-06-01 00:16:46,1,.00,1,N,145,145,2,3,0.5,0.5,0,0,0.3,4.3', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=83, serialized_header_size=-1)
# JSON created for 3 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:15:40", "tpep_dropoff_datetime" : "2018-06-01 00:16:46", "passenger_count" : 1, "trip_distance" : 0.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 145, "DOLocationID" : 145, "payment_type" : 2, "fare_amount" : 3, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 4.3}
# NO ERROR for 3 th message insert
# Successful write for 3 message number as 1 the insert into Mongo
# 1 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:15:40", "tpep_dropoff_datetime" : "2018-06-01 00:16:46", "passenger_count" : 1, "trip_distance" : 0.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 145, "DOLocationID" : 145, "payment_type" : 2, "fare_amount" : 3, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 4.3}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=3, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:04:18,2018-06-01 00:09:18,1,1.00,1,N,230,161,1,5.5,0.5,0.5,1.35,0,0.3,8.15', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=90, serialized_header_size=-1)
# JSON created for 4 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:04:18", "tpep_dropoff_datetime" : "2018-06-01 00:09:18", "passenger_count" : 1, "trip_distance" : 1.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 230, "DOLocationID" : 161, "payment_type" : 1, "fare_amount" : 5.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 1.35, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 8.15}
# NO ERROR for 4 th message insert
# Successful write for 4 message number as 2 the insert into Mongo
# 2 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:04:18", "tpep_dropoff_datetime" : "2018-06-01 00:09:18", "passenger_count" : 1, "trip_distance" : 1.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 230, "DOLocationID" : 161, "payment_type" : 1, "fare_amount" : 5.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 1.35, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 8.15}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=4, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:14:39,2018-06-01 00:29:46,1,3.30,1,N,100,263,2,13,0.5,0.5,0,0,0.3,14.3', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=86, serialized_header_size=-1)
# JSON created for 5 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:14:39", "tpep_dropoff_datetime" : "2018-06-01 00:29:46", "passenger_count" : 1, "trip_distance" : 3.30, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 100, "DOLocationID" : 263, "payment_type" : 2, "fare_amount" : 13, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 14.3}
# NO ERROR for 5 th message insert
# Successful write for 5 message number as 3 the insert into Mongo
# 3 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:14:39", "tpep_dropoff_datetime" : "2018-06-01 00:29:46", "passenger_count" : 1, "trip_distance" : 3.30, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 100, "DOLocationID" : 263, "payment_type" : 2, "fare_amount" : 13, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 14.3}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=5, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:51:25,2018-06-01 00:51:29,3,.00,1,N,145,145,2,2.5,0.5,0.5,0,0,0.3,3.8', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=85, serialized_header_size=-1)
# JSON created for 6 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:51:25", "tpep_dropoff_datetime" : "2018-06-01 00:51:29", "passenger_count" : 3, "trip_distance" : 0.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 145, "DOLocationID" : 145, "payment_type" : 2, "fare_amount" : 2.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 3.8}
# NO ERROR for 6 th message insert
# Successful write for 6 message number as 4 the insert into Mongo
# 4 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:51:25", "tpep_dropoff_datetime" : "2018-06-01 00:51:29", "passenger_count" : 3, "trip_distance" : 0.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 145, "DOLocationID" : 145, "payment_type" : 2, "fare_amount" : 2.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 3.8}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=6, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:55:06,2018-06-01 00:55:10,1,.00,1,N,145,145,2,2.5,0.5,0.5,0,0,0.3,3.8', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=85, serialized_header_size=-1)
# JSON created for 7 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:55:06", "tpep_dropoff_datetime" : "2018-06-01 00:55:10", "passenger_count" : 1, "trip_distance" : 0.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 145, "DOLocationID" : 145, "payment_type" : 2, "fare_amount" : 2.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 3.8}
# NO ERROR for 7 th message insert
# Successful write for 7 message number as 5 the insert into Mongo
# 5 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:55:06", "tpep_dropoff_datetime" : "2018-06-01 00:55:10", "passenger_count" : 1, "trip_distance" : 0.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 145, "DOLocationID" : 145, "payment_type" : 2, "fare_amount" : 2.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 3.8}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=7, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:09:00,2018-06-01 00:24:01,1,2.00,1,N,161,234,1,11.5,0.5,0.5,2.55,0,0.3,15.35', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# JSON created for 8 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:09:00", "tpep_dropoff_datetime" : "2018-06-01 00:24:01", "passenger_count" : 1, "trip_distance" : 2.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 161, "DOLocationID" : 234, "payment_type" : 1, "fare_amount" : 11.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 2.55, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 15.35}
# NO ERROR for 8 th message insert
# Successful write for 8 message number as 6 the insert into Mongo
# 6 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:09:00", "tpep_dropoff_datetime" : "2018-06-01 00:24:01", "passenger_count" : 1, "trip_distance" : 2.00, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 161, "DOLocationID" : 234, "payment_type" : 1, "fare_amount" : 11.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 2.55, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 15.35}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=8, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:02:33,2018-06-01 00:13:01,2,1.50,1,N,163,233,1,8.5,0.5,0.5,1.95,0,0.3,11.75', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=91, serialized_header_size=-1)
# JSON created for 9 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:02:33", "tpep_dropoff_datetime" : "2018-06-01 00:13:01", "passenger_count" : 2, "trip_distance" : 1.50, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 163, "DOLocationID" : 233, "payment_type" : 1, "fare_amount" : 8.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 1.95, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 11.75}
# NO ERROR for 9 th message insert
# Successful write for 9 message number as 7 the insert into Mongo
# 7 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:02:33", "tpep_dropoff_datetime" : "2018-06-01 00:13:01", "passenger_count" : 2, "trip_distance" : 1.50, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 163, "DOLocationID" : 233, "payment_type" : 1, "fare_amount" : 8.5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 1.95, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 11.75}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=9, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:13:23,2018-06-01 00:16:52,1,.70,1,N,186,246,1,5,0.5,0.5,1.85,0,0.3,8.15', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=87, serialized_header_size=-1)
# JSON created for 10 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:13:23", "tpep_dropoff_datetime" : "2018-06-01 00:16:52", "passenger_count" : 1, "trip_distance" : 0.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 186, "DOLocationID" : 246, "payment_type" : 1, "fare_amount" : 5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 1.85, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 8.15}
# NO ERROR for 10 th message insert
# Successful write for 10 message number as 8 the insert into Mongo
# 8 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:13:23", "tpep_dropoff_datetime" : "2018-06-01 00:16:52", "passenger_count" : 1, "trip_distance" : 0.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 186, "DOLocationID" : 246, "payment_type" : 1, "fare_amount" : 5, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 1.85, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 8.15}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=10, timestamp=1546342876796, timestamp_type=0, key=None, value=b'1,2018-06-01 00:24:29,2018-06-01 01:08:43,1,5.70,1,N,230,179,2,22,0.5,0.5,0,0,0.3,23.3', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=86, serialized_header_size=-1)
# JSON created for 11 th message::
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:24:29", "tpep_dropoff_datetime" : "2018-06-01 01:08:43", "passenger_count" : 1, "trip_distance" : 5.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 230, "DOLocationID" : 179, "payment_type" : 2, "fare_amount" : 22, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 23.3}
# NO ERROR for 11 th message insert
# Successful write for 11 message number as 9 the insert into Mongo
# 9 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 00:24:29", "tpep_dropoff_datetime" : "2018-06-01 01:08:43", "passenger_count" : 1, "trip_distance" : 5.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 230, "DOLocationID" : 179, "payment_type" : 2, "fare_amount" : 22, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 23.3}
# Full message received from Kafka::
#  ConsumerRecord(topic='TestNYTFullJuneButOnlyFirst12', partition=0, offset=11, timestamp=1546342876796, timestamp_type=0, key=None, value=b'2,2018-06-01 00:17:01,2018-06-01 00:23:16,1,.85,1,N,179,223,2,6,0.5,0.5,0,0,0.3,7.3', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=83, serialized_header_size=-1)
# JSON created for 12 th message::
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-01 00:17:01", "tpep_dropoff_datetime" : "2018-06-01 00:23:16", "passenger_count" : 1, "trip_distance" : 0.85, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 179, "DOLocationID" : 223, "payment_type" : 2, "fare_amount" : 6, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 7.3}
# NO ERROR for 12 th message insert
# Successful write for 12 message number as 10 the insert into Mongo
# 10 th JSON builtup as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-01 00:17:01", "tpep_dropoff_datetime" : "2018-06-01 00:23:16", "passenger_count" : 1, "trip_distance" : 0.85, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 179, "DOLocationID" : 223, "payment_type" : 2, "fare_amount" : 6, "extra" : 0.5, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 7.3}
# Exited FOR LOOP
# Read total 12 messages from Kafka
#
# Written 10 documents to MongoDb
#
# Done processing. Normal exit from program at:  Tue Jan  1 15:33:41 2019
