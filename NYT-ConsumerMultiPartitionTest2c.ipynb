# %%
# CONSUMER 3    CONSUMER 3   Test 2 without Mongo Write
# -*- coding: utf-8 -*-
"""
Created on Sun Jan  6 11:35:20 2019

@author: RB
"""
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads
from datetime import datetime

print('\nStart time of consumer program: ', datetime.now().strftime("%c"))

countDocsWritten1 = 0
countDocsWritten2 = 0
msgsReadCount = 0
topicName = 'TestNYTFullJuneDb10'

consumer = KafkaConsumer(
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
#     auto_offset_reset='latest',   # default is latest
     enable_auto_commit=True,
     auto_commit_interval_ms=2000,
     group_id='my-group4')
#     consumer_timeout_ms=5000)   #consumer_timeout_ms (int) – number of milliseconds to block during 
                                 #    message iteration before raising StopIteration (i.e., ending the 
                                 #    iterator). Default block forever [float(‘inf’)].
consumer.subscribe(topicName)

client1 = MongoClient('localhost:27017')
client2 = MongoClient('localhost:27017')
collection1 = client1.TestNYTFullJuneDb13.TestNYTFullJuneColJun01to12
collection2 = client2.TestNYTFullJuneDb13.TestNYTFullJuneColJun13to24

boundLowerPUDatetime1 = '2018-06-01 00:00:00'   # the pickup datetime from csv to be greater or equal to this
boundUpperPUDatetime1 = '2018-06-13 00:00:00'   # the pickup datetime from csv to be lower than this
boundLowerPUDatetime2 = '2018-06-13 00:00:00'   # the pickup datetime from csv to be greater or equal to this
boundUpperPUDatetime2 = '2018-06-25 00:00:00'   # the pickup datetime from csv to be lower than this

for message in consumer:
    msgsReadCount = msgsReadCount + 1
    NYTNewRowJsonBuiltUpAsString = "{}"
    #print(f'Msg number {msgsReadCount}::::\nFull message received from Kafka::\n', message)
    msgAsString = message.value.decode("utf-8")
    if msgAsString == '':
        print('IGNORED SECOND ROW with all commans, CONTINUING to end of the for loop')
        continue
    elif msgAsString[0:8] == 'VendorID':
        print('IGNORED FIRST ROW with columns names, CONTINUING to end of the for loop')
        continue
    elif msgAsString.count(',') == 16:
        msgAsList = msgAsString.split(",")
        trip_distanceAsString = str(msgAsList[4])
        if trip_distanceAsString[0:1] == '.':        # a 0 value comes as  .00  so checking and making as 0.00
            trip_distanceAsString = '0' + trip_distanceAsString
        NYTNewRowJsonBuiltUpAsString='{' +                                      \
        '"VendorID" : ' + str(msgAsList[0]) + ', ' +                            \
        '"tpep_pickup_datetime" : ' + '"' + str(msgAsList[1]) +  '"' + ', ' +   \
        '"tpep_dropoff_datetime" : ' + '"' + str(msgAsList[2]) +  '"' + ', ' +  \
        '"passenger_count" : ' + str(msgAsList[3]) + ', ' +                     \
        '"trip_distance" : ' + trip_distanceAsString + ', ' +                   \
        '"RatecodeID" : ' + str(msgAsList[5]) + ', ' +                          \
        '"store_and_fwd_flag" : ' + '"' + str(msgAsList[6]) + '"' + ', ' +      \
        '"PULocationID" : ' + str(msgAsList[7]) + ', ' +                        \
        '"DOLocationID" : ' + str(msgAsList[8]) + ', ' +                        \
        '"payment_type" : ' + str(msgAsList[9]) + ', ' +                        \
        '"fare_amount" : ' + str(msgAsList[10]) + ', ' +                        \
        '"extra" : ' + str(msgAsList[11]) + ', ' +                              \
        '"mta_tax" : ' + str(msgAsList[12]) + ', ' +                            \
        '"tip_amount" : ' + str(msgAsList[13]) + ', ' +                         \
        '"tolls_amount" : ' + str(msgAsList[14]) + ', ' +                       \
        '"improvement_surcharge" : ' + str(msgAsList[15]) + ', ' +              \
        '"total_amount" : ' + str(msgAsList[16]) + '}'
        #print(f'Msg {msgsReadCount} - JSON built as=\n{NYTNewRowJsonBuiltUpAsString}')
        if ( str(msgAsList[1]) < boundUpperPUDatetime1 and str(msgAsList[1]) >= boundLowerPUDatetime1 ):
            try:
                collection1.insert_one(loads(NYTNewRowJsonBuiltUpAsString))
                #print(f"Collection 1 -- NO ERROR for {msgsReadCount} th message insert")
                countDocsWritten1 = countDocsWritten1 + 1
                if countDocsWritten1 % 50000 == 0:
                    print(f"Collection 1 - write SUCCESS - {msgsReadCount} th message as {countDocsWritten1} th insert")
                if countDocsWritten1 % 250000 == 0:
                    print(f'Msg {msgsReadCount} - JSON built as=\n{NYTNewRowJsonBuiltUpAsString}')
            except Exception as e:
                print(f'Collection 1 ERROR Insert :: {msgsReadCount} th message\nError:: ', type(e), e)
        elif ( str(msgAsList[1]) < boundUpperPUDatetime2 and str(msgAsList[1]) >= boundLowerPUDatetime2 ):
            try:
                collection2.insert_one(loads(NYTNewRowJsonBuiltUpAsString))
                #print(f"Collection 2 -- NO ERROR for {msgsReadCount} th message insert")
                countDocsWritten2 = countDocsWritten2 + 1
                if countDocsWritten2 % 50000 == 0:
                    print(f"Collection 2 - write SUCCESS - {msgsReadCount} th message as {countDocsWritten2} th insert")
                if countDocsWritten2 % 500000 == 0:
                    print(f'Msg {msgsReadCount} - JSON built as=\n{NYTNewRowJsonBuiltUpAsString}')
            except Exception as e:
                print(f'Collection 2 ERROR Insert :: {msgsReadCount} th message\nError:: ', type(e), e)
    else:
        print(f"{msgsReadCount} th message NOT having 16 commas so IGNORED MESSAGE")


print('\nExited FOR LOOP\nRead total %d messages from Kafka' %(msgsReadCount))
print('\nWritten %d documents to Mongo Collection1' %(countDocsWritten1))
print('\nWritten %d documents to Mongo Collection2' %(countDocsWritten2))
print('\nDone processing. Normal exit from program at: ', datetime.now().strftime("%c"))
#
# ways to copy a dictionary value      dict2 = dict(dict1)   OR   dict2 = dict1.copy()
#
# Out:
# Start time of consumer program:  Sun Jan  6 16:45:28 2019
# Collection 1 - write SUCCESS - 50000 th message as 50000 th insert
# Collection 1 - write SUCCESS - 100000 th message as 100000 th insert
# Collection 1 - write SUCCESS - 150001 th message as 150000 th insert
# Collection 1 - write SUCCESS - 200001 th message as 200000 th insert
# Collection 1 - write SUCCESS - 250001 th message as 250000 th insert
# Msg 250001 - JSON built as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-03 14:43:45", "tpep_dropoff_datetime" : "2018-06-03 14:54:29", "passenger_count" : 4, "trip_distance" : 1.50, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 237, "DOLocationID" : 75, "payment_type" : 1, "fare_amount" : 9.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 2.05, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 12.35}
# Collection 1 - write SUCCESS - 300001 th message as 300000 th insert
# Collection 1 - write SUCCESS - 350001 th message as 350000 th insert
# Collection 1 - write SUCCESS - 400001 th message as 400000 th insert
# Collection 1 - write SUCCESS - 450001 th message as 450000 th insert
# Collection 1 - write SUCCESS - 500001 th message as 500000 th insert
# Msg 500001 - JSON built as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-06 08:29:22", "tpep_dropoff_datetime" : "2018-06-06 08:35:37", "passenger_count" : 1, "trip_distance" : 0.93, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 24, "DOLocationID" : 41, "payment_type" : 2, "fare_amount" : 6.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 7.3}
# Collection 1 - write SUCCESS - 550001 th message as 550000 th insert
# Collection 1 - write SUCCESS - 600001 th message as 600000 th insert
# Collection 1 - write SUCCESS - 650001 th message as 650000 th insert
# Collection 1 - write SUCCESS - 700001 th message as 700000 th insert
# Collection 1 - write SUCCESS - 750001 th message as 750000 th insert
# Msg 750001 - JSON built as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-08 15:04:44", "tpep_dropoff_datetime" : "2018-06-08 15:57:32", "passenger_count" : 1, "trip_distance" : 11.07, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 211, "DOLocationID" : 138, "payment_type" : 1, "fare_amount" : 40.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 8.26, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 51.51}
# Collection 1 - write SUCCESS - 800001 th message as 800000 th insert
# Collection 1 - write SUCCESS - 850001 th message as 850000 th insert
# Collection 1 - write SUCCESS - 900001 th message as 900000 th insert
# Collection 1 - write SUCCESS - 950001 th message as 950000 th insert
# Collection 1 - write SUCCESS - 1000001 th message as 1000000 th insert
# Msg 1000001 - JSON built as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-11 09:14:36", "tpep_dropoff_datetime" : "2018-06-11 09:20:09", "passenger_count" : 1, "trip_distance" : 0.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 186, "DOLocationID" : 230, "payment_type" : 2, "fare_amount" : 5.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 6.3}
# Collection 1 - write SUCCESS - 1050001 th message as 1050000 th insert
# Collection 1 - write SUCCESS - 1100004 th message as 1100000 th insert
# Collection 1 - write SUCCESS - 1150010 th message as 1150000 th insert
# Collection 2 - write SUCCESS - 1223283 th message as 50000 th insert
# Collection 2 - write SUCCESS - 1273283 th message as 100000 th insert
# Collection 2 - write SUCCESS - 1323283 th message as 150000 th insert
# Collection 2 - write SUCCESS - 1373283 th message as 200000 th insert
# Collection 2 - write SUCCESS - 1423283 th message as 250000 th insert
# Collection 2 - write SUCCESS - 1473283 th message as 300000 th insert
# Collection 2 - write SUCCESS - 1523283 th message as 350000 th insert
# Collection 2 - write SUCCESS - 1573283 th message as 400000 th insert
# Collection 2 - write SUCCESS - 1623283 th message as 450000 th insert
# Collection 2 - write SUCCESS - 1673283 th message as 500000 th insert
# Msg 1673283 - JSON built as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-18 10:21:25", "tpep_dropoff_datetime" : "2018-06-18 10:49:02", "passenger_count" : 2, "trip_distance" : 2.70, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 114, "DOLocationID" : 87, "payment_type" : 3, "fare_amount" : 17, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 17.8}
# Collection 2 - write SUCCESS - 1723283 th message as 550000 th insert
# Collection 2 - write SUCCESS - 1773283 th message as 600000 th insert
# Collection 2 - write SUCCESS - 1823283 th message as 650000 th insert
# Collection 2 - write SUCCESS - 1873283 th message as 700000 th insert
# Collection 2 - write SUCCESS - 1923283 th message as 750000 th insert
# Collection 2 - write SUCCESS - 1973283 th message as 800000 th insert
# Collection 2 - write SUCCESS - 2023283 th message as 850000 th insert
# Collection 2 - write SUCCESS - 2073283 th message as 900000 th insert
# Collection 2 - write SUCCESS - 2123283 th message as 950000 th insert
# Collection 2 - write SUCCESS - 2173283 th message as 1000000 th insert
# Msg 2173283 - JSON built as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-23 07:41:02", "tpep_dropoff_datetime" : "2018-06-23 07:44:08", "passenger_count" : 1, "trip_distance" : 0.60, "RatecodeID" : 1, "store_and_fwd_flag" : "Y", "PULocationID" : 238, "DOLocationID" : 239, "payment_type" : 1, "fare_amount" : 4.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 1.05, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 6.35}
# Collection 2 - write SUCCESS - 2223283 th message as 1050000 th insert
# Collection 2 - write SUCCESS - 2273283 th message as 1100000 th insert
# Collection 2 - write SUCCESS - 2323283 th message as 1150000 th insert
