# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Dec 31 14:08:19 2018

@author: RB
"""
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads
from datetime import datetime

print('\nStart time of consumer program: ', datetime.now().strftime("%c"))

countDocsWritten = 0
msgsReadCount = 0
topicName = 'TestNYTFullJuneButOnly24hrs'

consumer = KafkaConsumer(
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
#     auto_offset_reset='latest',   # default is latest
     enable_auto_commit=True,
     #auto_commit_interval_ms=2000,
#     group_id='my-group1',
     consumer_timeout_ms=5000)   #consumer_timeout_ms (int) – number of milliseconds to block during 
                                 #    message iteration before raising StopIteration (i.e., ending the 
                                 #    iterator). Default block forever [float(‘inf’)].
consumer.subscribe(topicName)

client = MongoClient('localhost:27017')
collection = client.TestNYTFullJuneButOnly24hrsDb1.TestNYTFullJuneButOnly24hrsCol1

for message in consumer:
    msgsReadCount = msgsReadCount + 1
    NYTNewRowJsonBuiltUpAsString = "{}"
#    print(f'Full message received from Kafka::\n', message)
    msgAsString = message.value.decode("utf-8")
    if msgAsString == '':
        print('IGNORED SECOND ROW with all commans, SKIPPING to end of the for loop')
        continue
    elif msgAsString[0:8] == 'VendorID':
        print('IGNORED FIRST ROW with columns names, SKIPPING to end of the for loop')
        continue
    elif msgAsString.count(',') == 16:
        msgAsList = msgAsString.split(",")
        trip_distanceAsString = str(msgAsList[4])
        if trip_distanceAsString[0:1] == '.':
            trip_distanceAsString = '0' + trip_distanceAsString
        NYTNewRowJsonBuiltUpAsString='{' +                                      \
        '"VendorID" : ' + str(msgAsList[0]) + ', ' +                            \
        '"tpep_pickup_datetime" : ' + '"' + str(msgAsList[1]) +  '"' + ', ' +   \
        '"tpep_dropoff_datetime" : ' + '"' + str(msgAsList[2]) +  '"' + ', ' +  \
        '"passenger_count" : ' + str(msgAsList[3]) + ', ' +                     \
        '"trip_distance" : ' + trip_distanceAsString + ', ' +                   \
        '"RatecodeID" : ' + str(msgAsList[5]) + ', ' +                          \
        '"store_and_fwd_flag" : ' + '"' + str(msgAsList[6]) + '"' + ', ' +      \
        '"PULocationID" : ' + str(msgAsList[7]) + ', ' +                        \
        '"DOLocationID" : ' + str(msgAsList[8]) + ', ' +                        \
        '"payment_type" : ' + str(msgAsList[9]) + ', ' +                        \
        '"fare_amount" : ' + str(msgAsList[10]) + ', ' +                        \
        '"extra" : ' + str(msgAsList[11]) + ', ' +                              \
        '"mta_tax" : ' + str(msgAsList[12]) + ', ' +                            \
        '"tip_amount" : ' + str(msgAsList[13]) + ', ' +                         \
        '"tolls_amount" : ' + str(msgAsList[14]) + ', ' +                       \
        '"improvement_surcharge" : ' + str(msgAsList[15]) + ', ' +              \
        '"total_amount" : ' + str(msgAsList[16]) + '}'
#        print(f'JSON created for {msgsReadCount} th message::\n{NYTNewRowJsonBuiltUpAsString}')
        try:
            collection.insert_one(loads(NYTNewRowJsonBuiltUpAsString))
#            print(f"NO ERROR for {msgsReadCount} th message insert")
            countDocsWritten = countDocsWritten + 1
            if countDocsWritten % 25000 == 0:
                print(f"Successful write for {msgsReadCount} message number as {countDocsWritten} the insert into Mongo")
            if countDocsWritten % 100000 == 0:
                print(f'{countDocsWritten} th JSON builtup as=\n{NYTNewRowJsonBuiltUpAsString}')
        except Exception as e:
            print(f'Error on Insert:: {msgsReadCount} th message\nError:: ', type(e), e)
    else:
        print(f"{msgsReadCount} th message NOT having 16 commas so IGNORED MESSAGE")


print('\nExited FOR LOOP\nRead total %d messages from Kafka' %(msgsReadCount))
print('\nWritten %d documents to MongoDb' %(countDocsWritten))
print('\nDone processing. Normal exit from program at: ', datetime.now().strftime("%c"))
#
# ways to copy a dictionary value      dict2 = dict(dict1)   OR   dict2 = dict1.copy()
#
# Out:
# Start time of consumer program:  Wed Jan  2 11:31:52 2019
# Successful write for 25000 message number as 25000 the insert into Mongo
# Successful write for 50000 message number as 50000 the insert into Mongo
# Successful write for 75000 message number as 75000 the insert into Mongo
# Successful write for 100000 message number as 100000 the insert into Mongo
# 100000 th JSON builtup as=
# {"VendorID" : 1, "tpep_pickup_datetime" : "2018-06-01 11:43:09", "tpep_dropoff_datetime" : "2018-06-01 11:48:16", "passenger_count" : 1, "trip_distance" : 0.90, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 43, "DOLocationID" : 239, "payment_type" : 1, "fare_amount" : 5.5, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 1.25, "tolls_amount" : 0, "improvement_surcharge" : 0.3, "total_amount" : 7.55}
# Successful write for 125000 message number as 125000 the insert into Mongo
# Successful write for 150000 message number as 150000 the insert into Mongo
# Successful write for 175000 message number as 175000 the insert into Mongo
# Successful write for 200000 message number as 200000 the insert into Mongo
# 200000 th JSON builtup as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-01 17:16:06", "tpep_dropoff_datetime" : "2018-06-01 18:12:24", "passenger_count" : 1, "trip_distance" : 15.21, "RatecodeID" : 1, "store_and_fwd_flag" : "N", "PULocationID" : 261, "DOLocationID" : 138, "payment_type" : 1, "fare_amount" : 48, "extra" : 1, "mta_tax" : 0.5, "tip_amount" : 11.11, "tolls_amount" : 5.76, "improvement_surcharge" : 0.3, "total_amount" : 66.67}
# Successful write for 225000 message number as 225000 the insert into Mongo
# Successful write for 250000 message number as 250000 the insert into Mongo
# Successful write for 275000 message number as 275000 the insert into Mongo
# Successful write for 300000 message number as 300000 the insert into Mongo
# 300000 th JSON builtup as=
# {"VendorID" : 2, "tpep_pickup_datetime" : "2018-06-01 22:51:20", "tpep_dropoff_datetime" : "2018-06-01 23:29:37", "passenger_count" : 2, "trip_distance" : 28.26, "RatecodeID" : 5, "store_and_fwd_flag" : "N", "PULocationID" : 132, "DOLocationID" : 187, "payment_type" : 1, "fare_amount" : 95, "extra" : 0, "mta_tax" : 0.5, "tip_amount" : 0, "tolls_amount" : 11.52, "improvement_surcharge" : 0.3, "total_amount" : 107.32}
#
# Exited FOR LOOP
# Read total 320529 messages from Kafka
#
# Written 320529 documents to MongoDb
#
# Done processing. Normal exit from program at:  Wed Jan  2 11:36:18 2019
